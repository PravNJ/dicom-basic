# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install pydicom
# Out:
# ...
#      |████████████████████████████████| 2.0 MB 14.9 MB/s
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
from pydicom import dcmread #function that reads dicom

#this is a comment you can pout garbage here and the program wont break

# %%
#path to a single file
FILE_PATH = '/content/drive/MyDrive/sample-2022-02-06/2.25.6796281463339927868571562783006522357.dcm'

# %%
#ds object stores data from dcmread
ds = dcmread(FILE_PATH)

# %%
#print some basic metadata
print()
print(f"File path........: {FILE_PATH}")
print(f"SOP Class........: {ds.SOPClassUID} ({ds.SOPClassUID.name})")
# Out:
# File path........: /content/drive/MyDrive/sample-2022-02-06/2.25.6796281463339927868571562783006522357.dcm
# SOP Class........: 1.2.840.10008.5.1.4.1.1.4.1 (Enhanced MR Image Storage)

# %%
import seaborn as sns 
plt.rcParams["figure.figsize"] = [16,9]
sns.set_style('whitegrid')

# %%
relevant_image_data = ds.pixel_array[33, 30:80, 20:90]

# %%
# plot the image using matplotlib
plt.imshow(relevant_image_data, cmap=plt.cm.viridis)

# %%
print( np.ndarray.min(relevant_image_data) )
print( np.ndarray.max(relevant_image_data) )
# Out:
# 6
# 24767

# %%
ax = plt.hist(relevant_image_data.ravel(), bins = 50)
plt.title("Grayscale Histogram")
plt.xlabel("grayscale value")
plt.ylabel("pixel count")
plt.show()
