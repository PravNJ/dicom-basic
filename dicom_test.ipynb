# %% [markdown]
# <a href="https://colab.research.google.com/github/PravNJ/dicom-basic/blob/main/dicom_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
#testing github connection
# Out:
# hello world

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install pydicom
# Out:
# Collecting pydicom
#   Downloading pydicom-2.2.2-py3-none-any.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 5.1 MB/s
# Installing collected packages: pydicom
# Successfully installed pydicom-2.2.2

# %%
import matplotlib.pyplot as plt
from pydicom import dcmread

# %%
#path to a single file
FILE_PATH = '/content/drive/My Drive/series-00000/image-00000.dcm'

# %%
#ds object stores data from dcmread
ds = dcmread(FILE_PATH)

# %%
#print some basic metadata
print()
print(f"File path........: {FILE_PATH}")
print(f"SOP Class........: {ds.SOPClassUID} ({ds.SOPClassUID.name})")
# Out:
# File path........: /content/drive/My Drive/series-00000/image-00000.dcm
# SOP Class........: 1.2.840.10008.5.1.4.1.1.2 (CT Image Storage)

# %%
# plot the image using matplotlib
plt.imshow(ds.pixel_array, cmap=plt.cm.gray)
plt.show()
